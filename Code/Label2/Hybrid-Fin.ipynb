# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import numpy as np
import random
import datetime
import matplotlib.pyplot as plt
import pip
pip.main(['install','seaborn'])
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.utils.class_weight import compute_class_weight
from keras.applications import DenseNet121, VGG19
from keras.models import Model
from keras.layers import Dense, Flatten, Dropout, LeakyReLU, GlobalAveragePooling2D, Conv2D, Input
from keras.optimizers import Adam
from keras.losses import BinaryFocalCrossentropy
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

modelclass = '2'
suffix = 'FIN'
iterations = 5
iterations2 = 5

def CreateModel(learn_rate):
    input_tensor = Input(shape=(256, 256, 3))
    base_model = VGG19(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

    for layer in base_model.layers[:10]:
        layer.trainable = False
        
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024)(x)
    x = LeakyReLU(negative_slope=0.01)(x)
    x = Dropout(0.5)(x)
    predictions = Dense(1, activation='sigmoid')(x)

    model = Model(inputs=base_model.input, outputs=predictions)
    model.compile(optimizer=Adam(learning_rate=learn_rate),
                  loss=BinaryFocalCrossentropy(),
                  metrics=['accuracy'])

    return model

base_dir = '../../Data/Arrays/'
class_dir = 'Converted Arrays/'
train_images = np.load(os.path.join(base_dir, 'train_images.npy'))
train_labels = np.load(os.path.join(class_dir, f'train_labels_class{modelclass}.npy'))
val_images = np.load(os.path.join(base_dir, 'val_images.npy'))
val_labels = np.load(os.path.join(class_dir, f'val_labels_class{modelclass}.npy'))

if len(train_images.shape) == 3:
    train_images = np.expand_dims(train_images, axis=-1)
    train_images = np.repeat(train_images, 3, axis=-1)

if len(val_images.shape) == 3:
    val_images = np.expand_dims(val_images, axis=-1)
    val_images = np.repeat(val_images, 3, axis=-1)

class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels.flatten())
class_weights = {i: class_weights[i] for i in range(len(class_weights))}

print("Initial class weights:", class_weights)
print("Start time: ", datetime.datetime.now())

best_model_path = f'Models/class{suffix}{modelclass}temp.keras'
model_checkpoint = ModelCheckpoint(best_model_path, monitor='val_loss', save_best_only=True, mode='min')

best_val_loss = float('inf')
for i in range(iterations):
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, min_lr=1e-7)
    model = CreateModel(1e-5)
    print(f"Training iteration {i+1}/{iterations}")
    history = model.fit(train_images, train_labels,
                        epochs=50,
                        batch_size=16,
                        validation_data=(val_images, val_labels),
                        class_weight=class_weights,
                        callbacks=[early_stopping, reduce_lr, model_checkpoint])

    model.load_weights(best_model_path)
    val_loss = min(history.history['val_loss'])
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        print(f"Best current val:{best_val_loss}")
        model.save(f'Models/class_{suffix}{modelclass}_overallbest.keras')

print("Training Complete")
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/conda/lib/python3.11/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /opt/conda/lib/python3.11/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/conda/lib/python3.11/site-packages (from seaborn) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Initial class weights: {0: 0.6261061946902655, 1: 2.482456140350877}
# Start time:  2025-01-16 08:59:02.551465
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1737017942.697567    1372 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1737017942.750758    1372 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1737017942.755919    1372 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1737017942.760015    1372 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1737017942.763096    1372 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1737017942.765971    1372 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1737017942.956516    1372 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1737017942.958411    1372 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1737017942.960055    1372 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Training iteration 1/5
# Epoch 1/50
# I0000 00:00:1737017954.962625    1431 service.cc:146] XLA service 0x7f72900076b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1737017954.962670    1431 service.cc:154]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
#   1/354 ━━━━━━━━━━━━━━━━━━━━ 2:06:32 22s/step - accuracy: 0.3750 - loss: 0.2862
# I0000 00:00:1737017973.589603    1431 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 353/354 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.4796 - loss: 0.1907
# E0000 00:00:1737018044.591017    1429 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1737018044.810897    1429 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 117s 269ms/step - accuracy: 0.4796 - loss: 0.1906 - val_accuracy: 0.8021 - val_loss: 0.1715 - learning_rate: 1.0000e-05
# Epoch 2/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 206ms/step - accuracy: 0.5875 - loss: 0.1738 - val_accuracy: 0.2836 - val_loss: 0.1734 - learning_rate: 1.0000e-05
# Epoch 3/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 75s 211ms/step - accuracy: 0.5056 - loss: 0.1725 - val_accuracy: 0.8021 - val_loss: 0.1711 - learning_rate: 1.0000e-05
# Epoch 4/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.4827 - loss: 0.1738 - val_accuracy: 0.8012 - val_loss: 0.1722 - learning_rate: 1.0000e-05
# Epoch 5/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.4772 - loss: 0.1739 - val_accuracy: 0.8021 - val_loss: 0.1716 - learning_rate: 1.0000e-05
# Epoch 6/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.6012 - loss: 0.1739 - val_accuracy: 0.8004 - val_loss: 0.1723 - learning_rate: 3.0000e-06
# Epoch 7/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.4945 - loss: 0.1741 - val_accuracy: 0.2235 - val_loss: 0.1758 - learning_rate: 3.0000e-06
# Epoch 8/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.4271 - loss: 0.1735 - val_accuracy: 0.3304 - val_loss: 0.1748 - learning_rate: 9.0000e-07
# Best current val:0.17110556364059448
# Training iteration 2/5
# Epoch 1/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 83s 221ms/step - accuracy: 0.5144 - loss: 0.1820 - val_accuracy: 0.7968 - val_loss: 0.1702 - learning_rate: 1.0000e-05
# Epoch 2/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 206ms/step - accuracy: 0.5047 - loss: 0.1725 - val_accuracy: 0.5654 - val_loss: 0.1729 - learning_rate: 1.0000e-05
# Epoch 3/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.4040 - loss: 0.1739 - val_accuracy: 0.7332 - val_loss: 0.1703 - learning_rate: 1.0000e-05
# Epoch 4/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 75s 211ms/step - accuracy: 0.5233 - loss: 0.1741 - val_accuracy: 0.7102 - val_loss: 0.1689 - learning_rate: 3.0000e-06
# Epoch 5/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.5500 - loss: 0.1754 - val_accuracy: 0.4876 - val_loss: 0.1750 - learning_rate: 3.0000e-06
# Epoch 6/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.4941 - loss: 0.1732 - val_accuracy: 0.4399 - val_loss: 0.1782 - learning_rate: 3.0000e-06
# Epoch 7/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.4947 - loss: 0.1734 - val_accuracy: 0.6193 - val_loss: 0.1709 - learning_rate: 9.0000e-07
# Epoch 8/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.6018 - loss: 0.1684 - val_accuracy: 0.4170 - val_loss: 0.1822 - learning_rate: 9.0000e-07
# Epoch 9/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.5316 - loss: 0.1698 - val_accuracy: 0.5627 - val_loss: 0.1737 - learning_rate: 2.7000e-07
# Best current val:0.16889148950576782
# Training iteration 3/5
# Epoch 1/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 81s 216ms/step - accuracy: 0.5003 - loss: 0.1968 - val_accuracy: 0.8021 - val_loss: 0.1726 - learning_rate: 1.0000e-05
# Epoch 2/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 206ms/step - accuracy: 0.5433 - loss: 0.1695 - val_accuracy: 0.2942 - val_loss: 0.1736 - learning_rate: 1.0000e-05
# Epoch 3/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 206ms/step - accuracy: 0.4821 - loss: 0.1729 - val_accuracy: 0.2111 - val_loss: 0.1734 - learning_rate: 1.0000e-05
# Epoch 4/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 206ms/step - accuracy: 0.4414 - loss: 0.1734 - val_accuracy: 0.4426 - val_loss: 0.1733 - learning_rate: 3.0000e-06
# Epoch 5/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.3930 - loss: 0.1764 - val_accuracy: 0.4205 - val_loss: 0.1733 - learning_rate: 3.0000e-06
# Epoch 6/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 206ms/step - accuracy: 0.4677 - loss: 0.1770 - val_accuracy: 0.4064 - val_loss: 0.1733 - learning_rate: 9.0000e-07
# Training iteration 4/5
# Epoch 1/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 81s 216ms/step - accuracy: 0.5060 - loss: 0.1923 - val_accuracy: 0.2367 - val_loss: 0.1739 - learning_rate: 1.0000e-05
# Epoch 2/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 206ms/step - accuracy: 0.4582 - loss: 0.1712 - val_accuracy: 0.2129 - val_loss: 0.1749 - learning_rate: 1.0000e-05
# Epoch 3/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.4608 - loss: 0.1714 - val_accuracy: 0.2730 - val_loss: 0.1737 - learning_rate: 1.0000e-05
# Epoch 4/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.4069 - loss: 0.1736 - val_accuracy: 0.3322 - val_loss: 0.1735 - learning_rate: 1.0000e-05
# Epoch 5/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 75s 211ms/step - accuracy: 0.4589 - loss: 0.1740 - val_accuracy: 0.8021 - val_loss: 0.1684 - learning_rate: 1.0000e-05
# Epoch 6/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 206ms/step - accuracy: 0.4813 - loss: 0.1733 - val_accuracy: 0.2332 - val_loss: 0.1741 - learning_rate: 1.0000e-05
# Epoch 7/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 206ms/step - accuracy: 0.3341 - loss: 0.1744 - val_accuracy: 0.3463 - val_loss: 0.1732 - learning_rate: 1.0000e-05
# Epoch 8/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 75s 211ms/step - accuracy: 0.5516 - loss: 0.1725 - val_accuracy: 0.7615 - val_loss: 0.1659 - learning_rate: 3.0000e-06
# Epoch 9/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.5888 - loss: 0.1690 - val_accuracy: 0.2845 - val_loss: 0.1819 - learning_rate: 3.0000e-06
# Epoch 10/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 75s 211ms/step - accuracy: 0.5030 - loss: 0.1732 - val_accuracy: 0.6696 - val_loss: 0.1658 - learning_rate: 3.0000e-06
# Epoch 11/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.5606 - loss: 0.1732 - val_accuracy: 0.5283 - val_loss: 0.1710 - learning_rate: 9.0000e-07
# Epoch 12/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 75s 211ms/step - accuracy: 0.5667 - loss: 0.1709 - val_accuracy: 0.6670 - val_loss: 0.1620 - learning_rate: 9.0000e-07
# Epoch 13/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.5726 - loss: 0.1724 - val_accuracy: 0.4753 - val_loss: 0.1772 - learning_rate: 9.0000e-07
# Epoch 14/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.6001 - loss: 0.1671 - val_accuracy: 0.5689 - val_loss: 0.1697 - learning_rate: 9.0000e-07
# Epoch 15/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.6113 - loss: 0.1656 - val_accuracy: 0.5724 - val_loss: 0.1699 - learning_rate: 2.7000e-07
# Epoch 16/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.5880 - loss: 0.1672 - val_accuracy: 0.6352 - val_loss: 0.1651 - learning_rate: 2.7000e-07
# Epoch 17/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.6012 - loss: 0.1707 - val_accuracy: 0.6281 - val_loss: 0.1657 - learning_rate: 1.0000e-07
# Best current val:0.16201286017894745
# Training iteration 5/5
# Epoch 1/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 82s 217ms/step - accuracy: 0.4570 - loss: 0.2018 - val_accuracy: 0.2341 - val_loss: 0.1756 - learning_rate: 1.0000e-05
# Epoch 2/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.4919 - loss: 0.1717 - val_accuracy: 0.7606 - val_loss: 0.1684 - learning_rate: 1.0000e-05
# Epoch 3/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 208ms/step - accuracy: 0.5223 - loss: 0.1737 - val_accuracy: 0.4223 - val_loss: 0.1748 - learning_rate: 1.0000e-05
# Epoch 4/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.5113 - loss: 0.1735 - val_accuracy: 0.6740 - val_loss: 0.1702 - learning_rate: 1.0000e-05
# Epoch 5/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 208ms/step - accuracy: 0.6190 - loss: 0.1719 - val_accuracy: 0.4302 - val_loss: 0.1743 - learning_rate: 3.0000e-06
# Epoch 6/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.4863 - loss: 0.1727 - val_accuracy: 0.4505 - val_loss: 0.1747 - learning_rate: 3.0000e-06
# Epoch 7/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5659 - loss: 0.1672 - val_accuracy: 0.5910 - val_loss: 0.1695 - learning_rate: 9.0000e-07
# Training Complete

# %%
best_model_path = f'Models/class{suffix}secondary{modelclass}temp.keras'
model_checkpoint = ModelCheckpoint(best_model_path, monitor='val_loss', save_best_only=True, mode='min')
best_val_loss = float('inf')
for i in range (iterations2):
    model = CreateModel(1e-7)
    model.load_weights(f'Models/class_{suffix}{modelclass}_overallbest.keras')
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=1e-8)
    
    print(f"Training iteration {i+1}/{iterations2}")
    history = model.fit(train_images, train_labels,
                        epochs=50,
                        batch_size=16,
                        validation_data=(val_images, val_labels),
                        class_weight=class_weights,
                        callbacks=[early_stopping, reduce_lr, model_checkpoint])

    model.load_weights(best_model_path)
    val_loss = min(history.history['val_loss'])
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        print(f"Best last val:{val_loss}")
        print(f"Best current val:{best_val_loss}")
        model.save(f'Models/class_{suffix}{modelclass}_overallbestFIN.keras')
# Out:
# /opt/conda/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 46 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# Training iteration 1/5
# Epoch 1/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 82s 220ms/step - accuracy: 0.6359 - loss: 0.1702 - val_accuracy: 0.6104 - val_loss: 0.1663 - learning_rate: 1.0000e-07
# Epoch 2/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.6038 - loss: 0.1679 - val_accuracy: 0.5945 - val_loss: 0.1675 - learning_rate: 1.0000e-07
# Epoch 3/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 208ms/step - accuracy: 0.5982 - loss: 0.1672 - val_accuracy: 0.5875 - val_loss: 0.1681 - learning_rate: 1.0000e-07
# Epoch 4/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5839 - loss: 0.1659 - val_accuracy: 0.5742 - val_loss: 0.1687 - learning_rate: 1.0000e-07
# Epoch 5/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 208ms/step - accuracy: 0.5835 - loss: 0.1673 - val_accuracy: 0.5724 - val_loss: 0.1685 - learning_rate: 1.0000e-08
# Epoch 6/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5855 - loss: 0.1685 - val_accuracy: 0.5804 - val_loss: 0.1683 - learning_rate: 1.0000e-08
# Best last val:0.16631367802619934
# Best current val:0.16631367802619934
# Training iteration 2/5
# Epoch 1/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 83s 221ms/step - accuracy: 0.6368 - loss: 0.1722 - val_accuracy: 0.6281 - val_loss: 0.1652 - learning_rate: 1.0000e-07
# Epoch 2/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.6071 - loss: 0.1676 - val_accuracy: 0.5954 - val_loss: 0.1674 - learning_rate: 1.0000e-07
# Epoch 3/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 82s 207ms/step - accuracy: 0.5901 - loss: 0.1697 - val_accuracy: 0.5998 - val_loss: 0.1672 - learning_rate: 1.0000e-07
# Epoch 4/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 208ms/step - accuracy: 0.5799 - loss: 0.1690 - val_accuracy: 0.5936 - val_loss: 0.1676 - learning_rate: 1.0000e-07
# Epoch 5/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5859 - loss: 0.1663 - val_accuracy: 0.5972 - val_loss: 0.1674 - learning_rate: 1.0000e-08
# Epoch 6/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5866 - loss: 0.1684 - val_accuracy: 0.5963 - val_loss: 0.1674 - learning_rate: 1.0000e-08
# Best last val:0.1651674211025238
# Best current val:0.1651674211025238
# Training iteration 3/5
# Epoch 1/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 81s 217ms/step - accuracy: 0.6384 - loss: 0.1712 - val_accuracy: 0.6131 - val_loss: 0.1661 - learning_rate: 1.0000e-07
# Epoch 2/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.6040 - loss: 0.1681 - val_accuracy: 0.5892 - val_loss: 0.1677 - learning_rate: 1.0000e-07
# Epoch 3/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5803 - loss: 0.1679 - val_accuracy: 0.5883 - val_loss: 0.1680 - learning_rate: 1.0000e-07
# Epoch 4/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5829 - loss: 0.1689 - val_accuracy: 0.6104 - val_loss: 0.1664 - learning_rate: 1.0000e-07
# Epoch 5/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.6105 - loss: 0.1708 - val_accuracy: 0.6104 - val_loss: 0.1665 - learning_rate: 1.0000e-08
# Epoch 6/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.6040 - loss: 0.1695 - val_accuracy: 0.6104 - val_loss: 0.1665 - learning_rate: 1.0000e-08
# Training iteration 4/5
# Epoch 1/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 82s 218ms/step - accuracy: 0.6443 - loss: 0.1692 - val_accuracy: 0.6122 - val_loss: 0.1660 - learning_rate: 1.0000e-07
# Epoch 2/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 208ms/step - accuracy: 0.5965 - loss: 0.1699 - val_accuracy: 0.5981 - val_loss: 0.1669 - learning_rate: 1.0000e-07
# Epoch 3/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5926 - loss: 0.1683 - val_accuracy: 0.5936 - val_loss: 0.1675 - learning_rate: 1.0000e-07
# Epoch 4/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5849 - loss: 0.1692 - val_accuracy: 0.6166 - val_loss: 0.1656 - learning_rate: 1.0000e-07
# Epoch 5/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5889 - loss: 0.1699 - val_accuracy: 0.5981 - val_loss: 0.1672 - learning_rate: 1.0000e-07
# Epoch 6/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5945 - loss: 0.1680 - val_accuracy: 0.6087 - val_loss: 0.1669 - learning_rate: 1.0000e-07
# Epoch 7/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5893 - loss: 0.1689 - val_accuracy: 0.5981 - val_loss: 0.1673 - learning_rate: 1.0000e-07
# Epoch 8/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5866 - loss: 0.1697 - val_accuracy: 0.6034 - val_loss: 0.1672 - learning_rate: 1.0000e-08
# Epoch 9/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 74s 208ms/step - accuracy: 0.5807 - loss: 0.1685 - val_accuracy: 0.6042 - val_loss: 0.1671 - learning_rate: 1.0000e-08
# Training iteration 5/5
# Epoch 1/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 81s 217ms/step - accuracy: 0.6413 - loss: 0.1696 - val_accuracy: 0.6069 - val_loss: 0.1664 - learning_rate: 1.0000e-07
# Epoch 2/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.5993 - loss: 0.1700 - val_accuracy: 0.5945 - val_loss: 0.1672 - learning_rate: 1.0000e-07
# Epoch 3/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.5778 - loss: 0.1709 - val_accuracy: 0.6060 - val_loss: 0.1665 - learning_rate: 1.0000e-07
# Epoch 4/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.6070 - loss: 0.1690 - val_accuracy: 0.5928 - val_loss: 0.1674 - learning_rate: 1.0000e-07
# Epoch 5/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.5932 - loss: 0.1701 - val_accuracy: 0.5989 - val_loss: 0.1672 - learning_rate: 1.0000e-08
# Epoch 6/50
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 73s 207ms/step - accuracy: 0.6070 - loss: 0.1705 - val_accuracy: 0.5981 - val_loss: 0.1671 - learning_rate: 1.0000e-08

# %%
test_images = np.load(os.path.join(base_dir, 'test_images.npy'))
test_labels = np.load(os.path.join(class_dir, f'test_labels_class{modelclass}.npy'))
test_image_names = np.load(os.path.join(base_dir, 'test_image_names.npy'), allow_pickle=True)

if len(test_images.shape) == 3:
    test_images = np.expand_dims(test_images, axis=-1)
    test_images = np.repeat(test_images, 3, axis=-1)

test_loss, test_accuracy = model.evaluate(test_images, test_labels, verbose=1)

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

y_pred = model.predict(test_images)
y_pred_binary = (y_pred > 0.5).astype(int)

cm = confusion_matrix(test_labels, y_pred_binary)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

def display_image_with_predictions(image, image_name, actual_label, predicted_label, likelihood):
    plt.imshow(image.squeeze(), cmap='gray')
    plt.title(f"Image: {image_name}\nActual: {actual_label}\nPredicted: {predicted_label}\nLikelihood: {likelihood:.4f}")
    plt.axis('off')
    plt.show()

num_samples = 20
indices = random.sample(range(test_images.shape[0]), num_samples)

for idx in indices:
    image = test_images[idx]
    image_name = test_image_names[idx]
    actual_label = test_labels[idx][0]
    image_expanded = np.expand_dims(image, axis=0)
    prediction = model.predict(image_expanded)[0][0]
    
    threshold = 0.5
    predicted_label = int(prediction > threshold)
    likelihood = prediction
    
    display_image_with_predictions(image, image_name, actual_label, predicted_label, likelihood)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 24s 556ms/step - accuracy: 0.6072 - loss: 0.1671
# Test Loss: 0.16680453717708588
# Test Accuracy: 0.6132450103759766
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 181ms/step
# E0000 00:00:1737024086.674547    1429 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1737024086.870870    1429 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
